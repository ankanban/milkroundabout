# %%
from milk import DataReader

# %%
reader = DataReader()

# %%
vdfs = reader.get_vacancies_df()
skills_df = reader.get_skills_df(vdfs)

# %%
skills_df
# Out:
#      approved     category               company     id  job_id  \
# 0        True  engineering  Amazon Instant Video    171    2239
# 1        True  engineering  Amazon Instant Video    192    2239
# 2        True  engineering  Amazon Instant Video    193    2239
# 3        True  engineering  Amazon Instant Video    202    2239
# 4       False         None  Amazon Instant Video  31018    2278
# 5        True      product  Amazon Instant Video    216    2273
# 6        True      product  Amazon Instant Video    236    2273
# 7        True      product  Amazon Instant Video    250    2273
# 8        True      product  Amazon Instant Video    268    2273
# 9        True      product  Amazon Instant Video    216    2272
# 10       True      product  Amazon Instant Video    236    2272
# 11       True      product  Amazon Instant Video    250    2272
# 12       True      product  Amazon Instant Video    268    2272
# 13       True      product  Amazon Instant Video    216    2258
# ...

# %%
skills_df[skills_df['name'] == 'Python'][['company', 'job_id']]
# Out:
#                                        company  job_id
# 46                                       EDITD    1623
# 50                                       EDITD    1624
# 93                                    Nestoria    1661
# 171                      Zoopla Property Group    1737
# 183                                    Ometria    1593
# 191                                    Ometria    1591
# 192                           Digital Catapult    2131
# 195                                Yoyo Wallet    1640
# 198                                Yoyo Wallet    1642
# 241                            What Now Travel    1818
# 244                            What Now Travel    1816
# 253                                   Arachnys    1759
# 318                                       Hudl    1969
# 369                                      Shopa    1557
# 372                                      Shopa    1556
# 407                              Swoon Editons    1511
# ...
